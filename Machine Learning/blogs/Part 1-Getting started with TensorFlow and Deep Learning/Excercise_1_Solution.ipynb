# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishit-dagli/Deep-Learning-With-TensorFlow-Blog-series/blob/master/Part%201-Getting%20started%20with%20TensorFlow%20and%20Deep%20Learning/Excercise_1_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
from tensorflow import keras
# Out:
# TensorFlow 2.x selected.

# %%
def house_model(y_new):
    xs=[]
    ys=[]
    for i in range(1,10):
        xs.append(i)
        ys.append((1+float(i))*50)
    
    xs=np.array(xs,dtype=float)
    ys=np.array(ys, dtype=float)

    model = keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
    model.compile(optimizer='sgd', loss='mean_squared_error')    
    
    model.fit(xs, ys, epochs = 4500)
    return (model.predict(y_new)[0]/100)

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Train on 9 samples
# Epoch 1/4500
# 9/9 [==============================] - 0s 18ms/sample - loss: 110458.0234
# Epoch 2/4500
# 9/9 [==============================] - 0s 429us/sample - loss: 13896.4170
# Epoch 3/4500
# 9/9 [==============================] - 0s 368us/sample - loss: 2012.7318
# Epoch 4/4500
# 9/9 [==============================] - 0s 227us/sample - loss: 548.0500
# Epoch 5/4500
# 9/9 [==============================] - 0s 327us/sample - loss: 365.3692
# Epoch 6/4500
# 9/9 [==============================] - 0s 190us/sample - loss: 340.4491
# Epoch 7/4500
# 9/9 [==============================] - 0s 180us/sample - loss: 334.9604
# Epoch 8/4500
# 9/9 [==============================] - 0s 190us/sample - loss: 331.8827
# Epoch 9/4500
# 9/9 [==============================] - 0s 205us/sample - loss: 329.1208
# Epoch 10/4500
# 9/9 [==============================] - 0s 199us/sample - loss: 326.4178
# Epoch 11/4500
# ...
